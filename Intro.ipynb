# %%
s1="this is my string class  "

# %%
len(s1)
# Out:
# 23

# %%
  s1.find('g')
# Out:
# 16

# %%
s1.find('is')
# Out:
# 2

# %%
s1.find('iS')
# Out:
# -1

# %%
s1.count('r')
# Out:
# 1

# %%
s1.upper()
# Out:
# 'THIS IS MY STRING CLASS'

# %%
s1.capitalize()
# Out:
# 'This is my string class'

# %%
s1+1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 s1+1
#
# TypeError: can only concatenate str (not "int") to str

# %%
s1+"sudh"
# Out:
# 'this is my string classsudh'

# %%
s1*4
# Out:
# 'this is my string classthis is my string classthis is my string classthis is my string class'

# %%
s1*2
# Out:
# 'this is my string classthis is my string class'

# %%
s1*2
# Out:
# 'this is my string classthis is my string class'

# %%
# tuyihgggjhl
# huhhbjnkhvhv
# gresfhgjhkjoj
# dcvbjfarfyguhjh
# bvbvhghnbncv

# %%
l=[1,345,"sudh",True,5+7j]

# %%
type(l)
# Out:
# list

# %%
l[3]
# Out:
# True

# %%
l[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 l[5]
#
# IndexError: list index out of range

# %%
l
# Out:
# [1, 345, 'sudh', True, (5+7j)]

# %%
l[0:5]
# Out:
# [1, 345, 'sudh', True, (5+7j)]

# %%
l[-1]
# Out:
# (5+7j)

# %%
l[::-1]
# Out:
# [(5+7j), True, 'sudh', 345, 1]

# %%
l[::2]
# Out:
# [1, 'sudh', (5+7j)]

# %%
s="pwskills"

# %%
list(s)
# Out:
# ['p', 'w', 's', 'k', 'i', 'l', 'l', 's']

# %%
l+list(s)
# Out:
# [1, 345, 'sudh', True, (5+7j), 'p', 'w', 's', 'k', 'i', 'l', 'l', 's']

# %%
l
# Out:
# [1, 345, 'sudh', True, (5+7j)]

# %%
l[2]
# Out:
# 'sudh'

# %%
l[2][0:2]
# Out:
# 'su'

# %%
type(l[2])
# Out:
# str

# %%
l[3]
# Out:
# True

# %%
str(l[3])
# Out:
# 'True'

# %%
str(l[3])[0:2]
# Out:
# 'Tr'

# %%
list[5]
# Out:
# list[5]

# %%
l+list(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 l+list(5)
#
# TypeError: 'int' object is not iterable

# %%
l1=[3,3,4,4,5]

# %%
l+l1
# Out:
# [1, 345, 'sudh', True, (5+7j), 3, 3, 4, 4, 5]

# %%
k=l+l1

# %%
k*3
# Out:
# [1,
#  345,
#  'sudh',
#  True,
#  (5+7j),
#  3,
#  3,
#  4,
#  4,
#  5,
#  1,
#  345,
#  'sudh',
#  True,
#  (5+7j),
#  3,
#  3,
#  4,
#  4,
#  5,
#  1,
#  345,
#  'sudh',
#  True,
#  (5+7j),
#  3,
#  3,
#  4,
#  4,
#  5]

# %%
 l.pop(7)
# Out:
# 7

# %%
l
# Out:
# [1, 345, 'sudh', True, (5+7j), 7, 7, 7]

# %%
l.append("pwskills")

# %%
l
# Out:
# [1, 345, 'sudh', True, (5+7j), 7, 7, 7, 'pwskills']

# %%
l.append(l1)

# %%
l
# Out:
# [1, 345, 'sudh', True, (5+7j), 7, 7, 7, 'pwskills', [3, 3, 4, 4, 5]]

# %%
l
# Out:
# [1, 345, 'sudh', True, (5+7j), 7, 7, 7, 'pwskills', [3, 3, 4, 4, 5]]

# %%
l.extend([3,4,5])

# %%
l
# Out:
# [1,
#  345,
#  'sudh',
#  True,
#  (5+7j),
#  7,
#  7,
#  7,
#  'pwskills',
#  [3, 3, 4, 4, 5],
#  3,
#  4,
#  5,
#  3,
#  4,
#  5]

# %%
l.extend("sudh")

# %%
l
# Out:
# [1,
#  345,
#  'sudh',
#  True,
#  (5+7j),
#  7,
#  7,
#  7,
#  'pwskills',
#  [3, 3, 4, 4, 5],
#  3,
#  4,
#  5,
#  3,
#  4,
#  5,
#  's',
#  'u',
#  'd',
#  'h']

# %%
k.insert(2,[3,4,5])

# %%
k
# Out:
# [1, 3, [3, 4, 5], 5, 4, 'sudh', (5+3j), 435.45]

# %%
k.insert(5,"oh")

# %%
k
# Out:
# [1, 3, [3, 4, 5], 5, 4, 'oh', 'sudh', (5+3j), 435.45]

# %%
k.insert(-1,45)

# %%
k
# Out:
# [1, 3, [3, 4, 5], 5, 4, 'oh', 'sudh', (5+3j), 45, 435.45]

# %%
k.pop(3)
# Out:
# 5

# %%
k
# Out:
# [1, 3, [3, 4, 5], 4, 'sudh', 45, 435.45]

# %%
k.pop(2)
# Out:
# [3, 4, 5]

# %%
k
# Out:
# [1, 3, 4, 'sudh', 45, 435.45]

# %%
k.extend("kon")

# %%
k
# Out:
# [1, 3, 5, 4, 'sudh', (5+3j), 435.45, 'k', 'o', 'n']

# %%
k.pop(5)
# Out:
# 'oh'

# %%
k
# Out:
# [1, 3, [3, 4, 5], 5, 4, 'sudh', 45, 435.45]

# %%
g=[1,3,4,5,[2,4,3,4,5],34.54,"sudh"]

# %%
g
# Out:
# [1, 3, 4, 5, [2, 4, 4, 5], 34.54, 'sudh']

# %%
g[4].remove(2)

# %%
g
# Out:
# [1, 3, 4, 5, [4, 4, 5], 34.54, 'sudh']

# %%
g[4].remove(4)

# %%
g
# Out:
# [1, 3, 4, 5, [4, 5], 34.54, 'sudh']

# %%
g.reverse()

# %%
g
# Out:
# ['sudh', 34.54, [4, 5], 5, 4, 3, 1]

# %%
g.index(5)
# Out:
# 3

# %%
y="a"

# %%
g.insert(0,a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 g.insert(0,a)
#
# NameError: name 'a' is not defined

# %%
g
# Out:
# ['sudh', 34.54, [4, 5], 5, 4, 3, 1]

# %%
j=[1,2,3,4,5]

# %%
j[0]
# Out:
# 1

# %%
j[0]=40

# %%
j[0]
# Out:
# 40

# %%
j
# Out:
# [40, 2, 3, 4, 5]

# %%
u="aman"

# %%
u.replace('a','s')
# Out:
# 'smsn'

# %%
t=(1,2,3,4,"sudh","aman",'ok') #tuple

# %%
t[0]="aman"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 t[0]="aman"
#
# TypeError: 'tuple' object does not support item assignment

# %%
t.index("sudh")
# Out:
# 4

# %%
type(t)
# Out:
# tuple

# %%
s1={}

# %%
type(s1)
# Out:
# dict

# %%
s1={1,2,3,4,5}

# %%
type(s1)
# Out:
# set

# %%
k=[1,3,5,4,"sudh",5+3j,435.45,[1,2,3]]

# %%
K
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 K
#
# NameError: name 'K' is not defined

# %%
 s3={1,2,3,4,3,2,5,6,5,4,3,67,6,7,7,6,66,6,6,5,5,33,3,5,55,3,4,4,6,8,9,2}

# %%
s3
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9, 33, 55, 66, 67}

# %%
 d1={}

# %%
type(d1)
# Out:
# dict

# %%
d2={"key":"value"}

# %%
d2
# Out:
# {'key': 'value'}

# %%
d3={"A":"aman","H":"himanshu",23:"january",2:"octobar"}

# %%
d3["A"]
# Out:
# 'aman'

# %%
d3[23]
# Out:
# 'january'

# %%
d3[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 d3[1]
#
# KeyError: 1

# %%
d5={'name':"sudh",'mail_id':"ss@gmail.com" , "name":"sudhanshu"}

# %%
d5['name']
# Out:
# 'sudhanshu'

# %%
d6={"number":[1,2,3,4,5],"assigment":(1,2,3,4),"launch_date":{1,12,3,4,5}}

# %% [markdown]
# d6

# %%
d6
# Out:
# {'number': [1, 2, 3, 4, 5],
#  'assigment': (1, 2, 3, 4),
#  'launch_date': {1, 3, 4, 5, 12}}

# %%
d6['mentor']=(1,2,4,5,4,3,2,4)

# %%
d6
# Out:
# {'number': [1, 2, 3, 4, 5],
#  'assigment': (1, 2, 3, 4),
#  'launch_date': {1, 3, 4, 5, 12},
#  'mentor': (1, 2, 4, 5, 4, 3, 2, 4)}

# %%
del d6['number']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 del d6['number']
#
# KeyError: 'number'

# %%
d6
# Out:
# {'assigment': (1, 2, 3, 4),
#  'launch_date': {1, 3, 4, 5, 12},
#  'mentor': (1, 2, 4, 5, 4, 3, 2, 4)}

# %%
list(d6.keys())
# Out:
# ['assigment', 'launch_date', 'mentor']

# %%
d6.values()
# Out:
# dict_values([(1, 2, 3, 4), {1, 3, 4, 5, 12}, (1, 2, 4, 5, 4, 3, 2, 4)])

# %%
list(d6.values())
# Out:
# [(1, 2, 3, 4), {1, 3, 4, 5, 12}, (1, 2, 4, 5, 4, 3, 2, 4)]

# %%
d6.items()
# Out:
# dict_items([('assigment', (1, 2, 3, 4)), ('launch_date', {1, 3, 4, 5, 12}), ('mentor', (1, 2, 4, 5, 4, 3, 2, 4))])

# %%
list(d6.items())
# Out:
# [('assigment', (1, 2, 3, 4)),
#  ('launch_date', {1, 3, 4, 5, 12}),
#  ('mentor', (1, 2, 4, 5, 4, 3, 2, 4))]

# %%
 d6.pop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 d6.pop()
#
# TypeError: pop expected at least 1 argument, got 0

# %%
d6.pop('assigment')
# Out:
# (1, 2, 3, 4)

# %%
d6
# Out:
# {'launch_date': {1, 3, 4, 5, 12}, 'mentor': (1, 2, 4, 5, 4, 3, 2, 4)}

# %%
marks= 981
if marks>=100:
  print("you got A++ grade")
elif marks<100 and marks>=80:
  print("you got A grade")
elif marks<80 and marks>=60:
  print("you got B grade")
else:
    print("fail")
# Out:
# you got A++ grade

# %%
marks= int(input("enter your marks"))
if marks>=100:
  print("you got A++ grade")
elif marks<100 and marks>=80:
  print("you got A grade")
elif marks<80 and marks>=60:
  print("you got B grade")
else:
    print("fail")
# Out:
# enter your marks 109
# you got A++ grade

# %%
5+3*2
# Out:
# 11

# %%
price = int(input("enter price"))
if price>1000:
     print("i will purchase")
     if price>=6000:
      print("i definatly purchase")
     elif price<2000:
         print("its ok")
elif
# Out:
# enter price 1899
# i will purchase
# its ok

# %%
l=(1,2,3,4,5,6)

# %%
l[2]
# Out:
# 3

# %%
l[2]+1
# Out:
# 4

# %%
l1=[]

# %%
l1.append(l[2]+1)

# %%
l1
# Out:
# [4, 4, 4]

# %%
l1
# Out:
# [4, 4, 4]

# %%
l1
# Out:
# [4, 4, 4, 4, 4]

# %%
l
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
for i in l:   #forloop
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
k1=[]
for b in l:
    print(b+2)
    k1.append(b+2)
k1
# Out:
# 3
# 4
# 5
# 6
# 7
# 8
# [3, 4, 5, 6, 7, 8]

# %%
k=['sudh','kumar','pwskills','course']

# %%
t=[]
for i in k:
    print(i)
    t.append(k.upper())
# Out:
# sudh
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[100], line 4
#       2 for i in k:
#       3     print(i)
# ----> 4     t.append(k.upper())
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
s=[]
for i in k:
    print(i)
    s.append(i.upper())
# Out:
# sudh
# kumar
# pwskills
# course

# %%
s
# Out:
# ['SUDH', 'KUMAR', 'PWSKILLS', 'COURSE']

# %%
j=[1,2,3,4,3.45,6.45,8.564,"aman","tonu","himanshu"]

# %%
j_num=[]
j_str=[]
 if

# %%
RS = int(input("enter RS"))
if RS > 1000:
    print("I will purshase")
     if RS>3000:
         print("to much")
     elif RS<2000:
         print("ok")
# Out:
#   Cell In[16], line 4
#     if RS>3000:
#     ^
# IndentationError: unexpected indent

# %%
h=[1,2,3,4,5,6]

# %%
h1=[]
for i in h:
     print(i+3)
     h1.append(i+3) 
h1
# Out:
# 4
# 5
# 6
# 7
# 8
# 9
# [4, 5, 6, 7, 8, 9]

# %%
h1
# Out:
# [4, 5, 6, 7, 8, 9]

# %%
k=["aman","himanshu","tonu","ankit"]

# %%
k1=[]
for i in k:
    print(i)
    k1.append(i.title())
k1
# Out:
# aman
# himanshu
# tonu
# ankit
# ['Aman', 'Himanshu', 'Tonu', 'Ankit']
